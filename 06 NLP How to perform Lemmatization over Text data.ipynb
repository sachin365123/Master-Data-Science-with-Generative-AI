# %% [markdown]
# **-----------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# *In this lecture we are going to explore:*
#
# 1. What is The Role of Lemmatization in NLP?
# 2. What are the differences between Stemming and Lemmatization?
# 3. What are Common Regex Functions used in NLP?
# 4. What are the Errors that Could Occur in Stemming?

# %% [markdown]
# **-----------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ![2.7_1_Lemmatization.png](attachment:f8a7dd99-0485-42a1-aa85-77f90095d0f6.png)

# %% [markdown]
# ![2.7_2_Lemmatization.png](attachment:2c11a983-70ed-4067-91dc-92c083b4e46e.png)

# %% [markdown]
# # 2.7 Lemmatization
#
# Where stemming removes the last few characters of a word, lemmatization stems the word to a more meaningful base form and ensures it does not lose it's meaning. Lemmatization works more intelligently, referencing a pre-defined dictionary containing the context of words and uses this when diminishing the word to the base form.
#
#
# * Lemmatization is a text pre-processing technique used in natural language processing (NLP) models to break a word down to its root meaning to identify similarities. For example, a lemmatization algorithm would reduce the word better to its root word, or lemme, good.
#
#
# * lemmatization aims to output dictionary base forms, it requires more robust morphological analysis than stemming.

# %%
connect_tokens = ['connecting', 'connected', 'connectivity', 'connect', 'connects']

# %%
learn_tokens = ['learned', 'learning', 'learn', 'learns', 'learner', 'learners']

# %%
likes_tokens = ['likes', 'better', 'worse']

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer

# %%
# create stemmer
ps = PorterStemmer()

# %%
for t in connect_tokens:
    print(t, " : ", ps.stem(t))
# Out:
# connecting  :  connect
# connected  :  connect
# connectivity  :  connect
# connect  :  connect
# connects  :  connect

# %%
for t in learn_tokens:
    print(t, " : ", ps.stem(t))
# Out:
# learned  :  learn
# learning  :  learn
# learn  :  learn
# learns  :  learn
# learner  :  learner
# learners  :  learner

# %%
for t in likes_tokens:
    print(t, " : ", ps.stem(t))
# Out:
# likes  :  like
# better  :  better
# worse  :  wors

# %% [markdown]
# ## Lemmatization

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\lnewb\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# create lemmatizer 
lemmatizer = WordNetLemmatizer()

# %%
for t in connect_tokens:
    print(t, " : ", lemmatizer.lemmatize(t))
# Out:
# connecting  :  connecting
# connected  :  connected
# connectivity  :  connectivity
# connect  :  connect
# connects  :  connects

# %%
for t in learn_tokens:
    print(t, " : ", lemmatizer.lemmatize(t))
# Out:
# learned  :  learned
# learning  :  learning
# learn  :  learn
# learns  :  learns
# learner  :  learner
# learners  :  learner

# %%
for t in likes_tokens:
    print(t, " : ", lemmatizer.lemmatize(t))
# Out:
# likes  :  like
# better  :  better
# worse  :  worse
